# %%
import json
from pprint import pprint

import requests

# Define the API URL
url = "https://deckofcardsapi.com/api/deck/new/shuffle/?deck_count=1"

# Make the request to the API
response = requests.get(url)

# If the request is successful, load the JSON content
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4))  # Print the formatted JSON data
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# {
#     "success": true,
#     "deck_id": "a6xeuy95bzik",
#     "remaining": 52,
#     "shuffled": true
# }

# %%
url = "https://deckofcardsapi.com/api/deck/a6xeuy95bzik/draw/?count=2"

# Make the request to the API
response = requests.get(url)

# If the request is successful, load the JSON content
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4))  # Print the formatted JSON data
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# {
#     "success": true,
#     "deck_id": "a6xeuy95bzik",
#     "cards": [
#         {
#             "code": "6D",
#             "image": "https://deckofcardsapi.com/static/img/6D.png",
#             "images": {
#                 "svg": "https://deckofcardsapi.com/static/img/6D.svg",
#                 "png": "https://deckofcardsapi.com/static/img/6D.png"
#             },
#             "value": "6",
#             "suit": "DIAMONDS"
#         },
#         {
#             "code": "6H",
#             "image": "https://deckofcardsapi.com/static/img/6H.png",
#             "images": {
#                 "svg": "https://deckofcardsapi.com/static/img/6H.svg",
#                 "png": "https://deckofcardsapi.com/static/img/6H.png"
#             },
#             "value": "6",
#             "suit": "HEARTS"
#         }
#     ],
#     "remaining": 50
# }

# %%
# Code from [2]
from PIL import Image
import requests
from io import BytesIO
url = "https://deckofcardsapi.com/static/img/6H.png"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=226x314>

# %%
# Code from [2]
import ipyplot

images_list = [url, url]

ipyplot.plot_images(images_list, max_images=20, img_width=150)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-cAVYCHSiYgUwFofryzicFa {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-cAVYCHSiYgUwFofryzicFa {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-cAVYCHSiYgUwFofryzicFa {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-cAVYCHSiYgUwFofryzicFa:checked ~ #ipyplot-html-viewer-textarea-cAVYCHSiYgUwFofryzicFa {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-cAVYCHSiYgUwFofryzicFa:checked + #ipyplot-html-viewer-label-cAVYCHSiYgUwFofryzicFa:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-cAVYCHSiYgUwFofryzicFa">
#         <label id="ipyplot-html-viewer-label-cAVYCHSiYgUwFofryzicFa" for="ipyplot-html-viewer-toggle-cAVYCHSiYgUwFofryzicFa">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-cAVYCHSiYgUwFofryzicFa" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-hQXYbKpFerDze8fn7WBfpB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-hQXYbKpFerDze8fn7WBfpB {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-hQXYbKpFerDze8fn7WBfpB">
#     <div class="ipyplot-placeholder-div-hQXYbKpFerDze8fn7WBfpB">
#         <div id="ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB-EiC3uaMw2i3uueBq8NtHbX" class="ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/6H.png</h4><img src="https://deckofcardsapi.com/static/img/6H.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB-EiC3uaMw2i3uueBq8NtHbX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hQXYbKpFerDze8fn7WBfpB">
#         <div id="ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB-5mxNWTRttnBD7VGdrkupje" class="ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/6H.png</h4><img src="https://deckofcardsapi.com/static/img/6H.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB-5mxNWTRttnBD7VGdrkupje">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-hQXYbKpFerDze8fn7WBfpB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-hQXYbKpFerDze8fn7WBfpB {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-hQXYbKpFerDze8fn7WBfpB">
#     <div class="ipyplot-placeholder-div-hQXYbKpFerDze8fn7WBfpB">
#         <div id="ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB-EiC3uaMw2i3uueBq8NtHbX" class="ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/6H.png</h4><img src="https://deckofcardsapi.com/static/img/6H.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB-EiC3uaMw2i3uueBq8NtHbX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hQXYbKpFerDze8fn7WBfpB">
#         <div id="ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB-5mxNWTRttnBD7VGdrkupje" class="ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/6H.png</h4><img src="https://deckofcardsapi.com/static/img/6H.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hQXYbKpFerDze8fn7WBfpB-5mxNWTRttnBD7VGdrkupje">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ### References
#
# 1. Geeksforgeeks.org response.json() - Python requests https://www.geeksforgeeks.org/response-json-python-requests/
# 2. Stack Overflow 2002 How do I read image data from a URL in Python? [Online] Available:https://stackoverflow.com/questions/7391945/how-do-i-read-image-data-from-a-url-in-python
