# %% [markdown]
# # Assignment 2: Deck of Cards
#
# Draw 5 cards from a desk (https://deckofcardsapi.com) and do a basic evaluation on the hand based on suit.

# %%
import json
from pprint import pprint
import requests

# https://deckofcardsapi.com/

deck_count = 1

# Define the API URL with number of decks to shuffle [4]
url = f"https://deckofcardsapi.com/api/deck/new/shuffle/?deck_count={deck_count}"

# Make the request to the API
response = requests.get(url)

# If the request is successful, load the JSON content
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4))  # Print the formatted JSON data
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# Get the deck ID
deck_id = data["deck_id"]
# Out:
# {
#     "success": true,
#     "deck_id": "4dagz0gzo860",
#     "remaining": 52,
#     "shuffled": true
# }

# %%
# Draw 5 cards

no_of_cards = 5

# Define the API URL to draw cards
url = f"https://deckofcardsapi.com/api/deck/{deck_id}/draw/?count={no_of_cards}"

# Make the request to the API
response = requests.get(url)

# If the request is successful, load the JSON content
if response.status_code == 200:
    data = response.json()
#    with open("cards.json", "w") as fp:
#        print(json.dumps(data, indent=4))  # Print the formatted JSON data
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# %%
card_image_url = []
card_suit = []
card_value = []
for card in data["cards"]:
    print(f"{card['value']} of {card['suit']}")
    card_image_url.append(card['image'])
    card_suit.append(card['suit'])
    card_value.append(card['value'])
# Out:
# QUEEN of CLUBS
# 7 of DIAMONDS
# 3 of DIAMONDS
# 9 of CLUBS
# 9 of DIAMONDS

# %%
# Code from [2]
import ipyplot
ipyplot.plot_images(card_image_url, max_images=5, img_width=70);
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4J4oJA7aY5P9ur3HM22Cq9 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4J4oJA7aY5P9ur3HM22Cq9 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4J4oJA7aY5P9ur3HM22Cq9 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4J4oJA7aY5P9ur3HM22Cq9:checked ~ #ipyplot-html-viewer-textarea-4J4oJA7aY5P9ur3HM22Cq9 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4J4oJA7aY5P9ur3HM22Cq9:checked + #ipyplot-html-viewer-label-4J4oJA7aY5P9ur3HM22Cq9:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-4J4oJA7aY5P9ur3HM22Cq9">
#         <label id="ipyplot-html-viewer-label-4J4oJA7aY5P9ur3HM22Cq9" for="ipyplot-html-viewer-toggle-4J4oJA7aY5P9ur3HM22Cq9">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-4J4oJA7aY5P9ur3HM22Cq9" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-PUz43Aqr9GRqk9z6ULy3QM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM {
#             width: 70px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM {
#             width: 70px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM img {
#             width: 70px;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-PUz43Aqr9GRqk9z6ULy3QM">
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-9PVFQfQHG8nGrNXFKyF6d2" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/QC.png</h4><img src="https://deckofcardsapi.com/static/img/QC.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-9PVFQfQHG8nGrNXFKyF6d2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-RLXwcPCw9qwrTdnqmHQBPB" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/7D.png</h4><img src="https://deckofcardsapi.com/static/img/7D.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-RLXwcPCw9qwrTdnqmHQBPB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-j9ET8W9qNwkL94tEtJcons" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/3D.png</h4><img src="https://deckofcardsapi.com/static/img/3D.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-j9ET8W9qNwkL94tEtJcons">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-CnGDdgDdHC3BxsB6y9oFfF" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/9C.png</h4><img src="https://deckofcardsapi.com/static/img/9C.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-CnGDdgDdHC3BxsB6y9oFfF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-HDoEm9pzYJjDuzzJx5oTnh" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/9D.png</h4><img src="https://deckofcardsapi.com/static/img/9D.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-HDoEm9pzYJjDuzzJx5oTnh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-PUz43Aqr9GRqk9z6ULy3QM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM {
#             width: 70px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM {
#             width: 70px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM img {
#             width: 70px;
#         }
#
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-PUz43Aqr9GRqk9z6ULy3QM">
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-9PVFQfQHG8nGrNXFKyF6d2" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/QC.png</h4><img src="https://deckofcardsapi.com/static/img/QC.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-9PVFQfQHG8nGrNXFKyF6d2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-RLXwcPCw9qwrTdnqmHQBPB" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/7D.png</h4><img src="https://deckofcardsapi.com/static/img/7D.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-RLXwcPCw9qwrTdnqmHQBPB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-j9ET8W9qNwkL94tEtJcons" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/3D.png</h4><img src="https://deckofcardsapi.com/static/img/3D.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-j9ET8W9qNwkL94tEtJcons">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-CnGDdgDdHC3BxsB6y9oFfF" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/9C.png</h4><img src="https://deckofcardsapi.com/static/img/9C.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-CnGDdgDdHC3BxsB6y9oFfF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PUz43Aqr9GRqk9z6ULy3QM">
#         <div id="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-HDoEm9pzYJjDuzzJx5oTnh" class="ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/9D.png</h4><img src="https://deckofcardsapi.com/static/img/9D.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PUz43Aqr9GRqk9z6ULy3QM-HDoEm9pzYJjDuzzJx5oTnh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
suits = ['SPADES', 'HEARTS', 'DIAMONDS', 'CLUBS']

# Create a dictionary to store number of cards of each suit
counts = {suit: 0 for suit in suits}

for suit in card_suit:
    counts[suit] += 1

# Print how many cards in each suit
print(counts)
# Out:
# {'SPADES': 0, 'HEARTS': 0, 'DIAMONDS': 3, 'CLUBS': 2}

# %%
# Evaluate the hand - goes thru the various permutations of pairs, triples etc

hand = max(counts.values())  

if  max(counts.values()) == 5:
  print("Wow - a flush") 
elif  max(counts.values()) == 4:  
  print("Pretty good - four of a kind")
elif 3 in counts.values() and 2 in counts.values():
  print("A triple and a pair - nice!")
elif 3 in counts.values() and 2 not in counts.values():
  print("A triple - not bad!")
elif list(counts.values()).count(2) == 2:
  print("Two pair - maybe something...")
elif list(counts.values()).count(2) == 1:
  print("One pair - bluff!")
# Out:
# A triple and a pair - nice!

# %% [markdown]
# ### References
#
# 1. Geeksforgeeks.org response.json() - Python requests [Online] Available: https://www.geeksforgeeks.org/response-json-python-requests/
# 2. Stack Overflow 2002 How do I read image data from a URL in Python? [Online] Available:https://stackoverflow.com/questions/7391945/how-do-i-read-image-data-from-a-url-in-python
# 3. Ipyplot https://github.com/karolzak/ipyplot
# 4. deckofcardsapi.com API Documentation [Online] Available: https://deckofcardsapi.com/
