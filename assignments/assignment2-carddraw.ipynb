# %% [markdown]
# # Assignment 2: Deck of Cards

# %%
import json
from pprint import pprint
import requests

# https://deckofcardsapi.com/

deck_count = 1

# Define the API URL with number of decks to shuffle [4]
url = f"https://deckofcardsapi.com/api/deck/new/shuffle/?deck_count={deck_count}"

# Make the request to the API
response = requests.get(url)

# If the request is successful, load the JSON content
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4))  # Print the formatted JSON data
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# Get the deck ID
deck_id = data["deck_id"]
# Out:
# {
#     "success": true,
#     "deck_id": "3q7egxo2f0i7",
#     "remaining": 52,
#     "shuffled": true
# }

# %%
# Draw 5 cards

no_of_cards = 5

# Define the API URL to draw cards
url = f"https://deckofcardsapi.com/api/deck/{deck_id}/draw/?count={no_of_cards}"

# Make the request to the API
response = requests.get(url)

# If the request is successful, load the JSON content
if response.status_code == 200:
    data = response.json()
    with open("cards.json", "w") as fp:
        print(json.dumps(data, indent=4))  # Print the formatted JSON data
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# {
#     "success": true,
#     "deck_id": "3q7egxo2f0i7",
#     "cards": [
#         {
#             "code": "JS",
#             "image": "https://deckofcardsapi.com/static/img/JS.png",
#             "images": {
#                 "svg": "https://deckofcardsapi.com/static/img/JS.svg",
#                 "png": "https://deckofcardsapi.com/static/img/JS.png"
#             },
#             "value": "JACK",
#             "suit": "SPADES"
#         },
#         {
#             "code": "4S",
#             "image": "https://deckofcardsapi.com/static/img/4S.png",
#             "images": {
#                 "svg": "https://deckofcardsapi.com/static/img/4S.svg",
#                 "png": "https://deckofcardsapi.com/static/img/4S.png"
#             },
#             "value": "4",
#             "suit": "SPADES"
#         },
#         {
#             "code": "9D",
#             "image": "https://deckofcardsapi.com/static/img/9D.png",
#             "images": {
#                 "svg": "https://deckofcardsapi.com/static/img/9D.svg",
#                 "png": "https://deckofcardsapi.com/static/img/9D.png"
#             },
#             "value": "9",
#             "suit": "DIAMONDS"
#         },
#         {
#             "code": "3H",
#             "image": "https://deckofcardsapi.com/static/img/3H.png",
#             "images": {
#                 "svg": "https://deckofcardsapi.com/static/img/3H.svg",
#                 "png": "https://deckofcardsapi.com/static/img/3H.png"
#             },
#             "value": "3",
#             "suit": "HEARTS"
#         },
#         {
#             "code": "KD",
#             "image": "https://deckofcardsapi.com/static/img/KD.png",
#             "images": {
#                 "svg": "https://deckofcardsapi.com/static/img/KD.svg",
#                 "png": "https://deckofcardsapi.com/static/img/KD.png"
#             },
#             "value": "KING",
#             "suit": "DIAMONDS"
#         }
#     ],
#     "remaining": 47
# }

# %%
card_image_url = []
card_suit = []
card_value = []
for card in data["cards"]:
    print(f"{card['value']} of {card['suit']}")
    card_image_url.append(card['image'])
    card_suit.append(card['suit'])
    card_value.append(card['value'])
# Out:
# JACK of SPADES
# 4 of SPADES
# 9 of DIAMONDS
# 3 of HEARTS
# KING of DIAMONDS

# %%
# Code from [2]
#from PIL import Image
#import requests
#from io import BytesIO
#url = "https://deckofcardsapi.com/static/img/6H.png"
#response = requests.get(url)
#img = Image.open(BytesIO(response.content))
#img

# %%
# Code from [2]
import ipyplot
ipyplot.plot_images(card_image_url, max_images=5, img_width=70);
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-35KUgDgKcBYNoXqRiWenPp {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-35KUgDgKcBYNoXqRiWenPp {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-35KUgDgKcBYNoXqRiWenPp {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-35KUgDgKcBYNoXqRiWenPp:checked ~ #ipyplot-html-viewer-textarea-35KUgDgKcBYNoXqRiWenPp {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-35KUgDgKcBYNoXqRiWenPp:checked + #ipyplot-html-viewer-label-35KUgDgKcBYNoXqRiWenPp:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-35KUgDgKcBYNoXqRiWenPp">
#         <label id="ipyplot-html-viewer-label-35KUgDgKcBYNoXqRiWenPp" for="ipyplot-html-viewer-toggle-35KUgDgKcBYNoXqRiWenPp">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-35KUgDgKcBYNoXqRiWenPp" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-8TCBr5dX9vv2R9kDjQLL6g {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g {
#             width: 70px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g {
#             width: 70px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g img {
#             width: 70px;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8TCBr5dX9vv2R9kDjQLL6g">
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-YyBBrnkj22gztzsq6JyCDZ" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/JS.png</h4><img src="https://deckofcardsapi.com/static/img/JS.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-YyBBrnkj22gztzsq6JyCDZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-HJj27QqYMKn5ixViBfJDCq" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/4S.png</h4><img src="https://deckofcardsapi.com/static/img/4S.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-HJj27QqYMKn5ixViBfJDCq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-XbgoqsLZqUeJQFHBNusgGz" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/9D.png</h4><img src="https://deckofcardsapi.com/static/img/9D.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-XbgoqsLZqUeJQFHBNusgGz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-jNniVeTFn9yTGGiwdtvW9w" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/3H.png</h4><img src="https://deckofcardsapi.com/static/img/3H.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-jNniVeTFn9yTGGiwdtvW9w">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-mAvVwjE4ub2oJoaTc5CGLg" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/KD.png</h4><img src="https://deckofcardsapi.com/static/img/KD.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-mAvVwjE4ub2oJoaTc5CGLg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-8TCBr5dX9vv2R9kDjQLL6g {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g {
#             width: 70px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g {
#             width: 70px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g img {
#             width: 70px;
#         }
#
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8TCBr5dX9vv2R9kDjQLL6g">
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-YyBBrnkj22gztzsq6JyCDZ" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/JS.png</h4><img src="https://deckofcardsapi.com/static/img/JS.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-YyBBrnkj22gztzsq6JyCDZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-HJj27QqYMKn5ixViBfJDCq" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/4S.png</h4><img src="https://deckofcardsapi.com/static/img/4S.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-HJj27QqYMKn5ixViBfJDCq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-XbgoqsLZqUeJQFHBNusgGz" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/9D.png</h4><img src="https://deckofcardsapi.com/static/img/9D.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-XbgoqsLZqUeJQFHBNusgGz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-jNniVeTFn9yTGGiwdtvW9w" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/3H.png</h4><img src="https://deckofcardsapi.com/static/img/3H.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-jNniVeTFn9yTGGiwdtvW9w">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8TCBr5dX9vv2R9kDjQLL6g">
#         <div id="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-mAvVwjE4ub2oJoaTc5CGLg" class="ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://deckofcardsapi.com/static/img/KD.png</h4><img src="https://deckofcardsapi.com/static/img/KD.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8TCBr5dX9vv2R9kDjQLL6g-mAvVwjE4ub2oJoaTc5CGLg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
suits = ['SPADES', 'HEARTS', 'DIAMONDS', 'CLUBS']

# Create a dictionary to store number of cards of each suit
counts = {suit: 0 for suit in suits}

for suit in card_suit:
    counts[suit] += 1

# Print how many cards in each suit
print(counts)
# Out:
# {'SPADES': 2, 'HEARTS': 1, 'DIAMONDS': 2, 'CLUBS': 0}

# %%
# Evaluate the hand - goes thru the various permutations of pairs, triples etc

hand = max(counts.values())  

if  max(counts.values()) == 5:
  print("Wow - a flush") 
elif  max(counts.values()) == 4:  
  print("Pretty good - four of a kind")
elif 3 in counts.values() and 2 in counts.values():
  print("A triple and a pair - nice!")
elif 3 in counts.values() and 2 not in counts.values():
  print("A triple - not bad!")
elif list(counts.values()).count(2) == 2:
  print("Two pair - maybe something...")
elif list(counts.values()).count(2) == 1:
  print("One pair - bluff!")
# Out:
# Two pair - maybe something...

# %% [markdown]
# ### References
#
# 1. Geeksforgeeks.org response.json() - Python requests [Online] Available: https://www.geeksforgeeks.org/response-json-python-requests/
# 2. Stack Overflow 2002 How do I read image data from a URL in Python? [Online] Available:https://stackoverflow.com/questions/7391945/how-do-i-read-image-data-from-a-url-in-python
# 3. Ipyplot https://github.com/karolzak/ipyplot
# 4. deckofcardsapi.com API Documentation [Online] Available: https://deckofcardsapi.com/
